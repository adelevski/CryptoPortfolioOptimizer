# %%
import datetime as dt
from tracker.tracker import get_owned
from optimizer.optimization import optimize

# %%
# assets = get_owned()                                    # My personal assets using the tracker
# assets = ['BTC-USD', 'ETH-USD', 'ADA-USD', 'BNB-USD']   # Crypto top 4 
assets = ['AMZN','AAPL', 'MSFT', 'FB']                  # SP500 top 4

# end_date = dt.datetime.now()
# start_date = end_date - dt.timedelta(days=180)     # Past 180 days

start_date = dt.datetime(2019, 1, 1)
end_date = dt.datetime(2020, 1, 1)                 # Full 2019 year

optimize(assets, start_date, end_date, log=False)
# Out:
# ...
# [*********************100%***********************]  4 of 4 completed
# Performing optimizations...
# Max Returns: [{'AAPL': 100.0}]
# Min Volatility: [{'AAPL': 9.7}, {'AMZN': 14.7}, {'FB': 11.4}, {'MSFT': 64.2}]
# Max Sharpe: [{'AAPL': 52.1}, {'FB': 2.6}, {'MSFT': 45.3}]
